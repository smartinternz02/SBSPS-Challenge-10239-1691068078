# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/Placement_Data_Full_Class - Placement_Data_Full_Class.csv')
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1    male  67.00   Others  91.00   Others  commerce     58.00
# 1        2    male  79.33  Central  78.33   Others   Science     77.48
# 2        3    male  65.00  Central  68.00  Central      Arts     64.00
# 3        4    male  56.00  Central  52.00  Central   Science     52.00
# 4        5    male  85.80  Central  73.60  Central  commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211    male  80.60   Others  82.00   Others  commerce     77.60
# 211    212    male  58.00   Others  60.00   Others   Science     72.00
# 212    213    male  67.00   Others  67.00   Others  commerce     73.00
# 213    214  female  74.00   Others  66.00   Others  commerce     58.00
# 214    215    male  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  project specialisation      status    salary
# 0     Sci&Tech     No        2           Java      Placed  270000.0
# 1     Sci&Tech    Yes        2           Java      Placed  200000.0
# 2    Comm&Mgmt     No        2           Java      Placed  250000.0
# 3     Sci&Tech     No        2           Java  Not Placed       NaN
# 4    Comm&Mgmt     No        2           Java      Placed  425000.0
# ..         ...    ...      ...            ...         ...       ...
# 210  Comm&Mgmt     No        2         python      Placed  400000.0
# 211   Sci&Tech     No        2         python      Placed  275000.0
# 212  Comm&Mgmt    Yes        2         python      Placed  295000.0
# 213  Comm&Mgmt     No        2         python      Placed  204000.0
# 214  Comm&Mgmt     No        2         python  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
px.pie(data,names='gender',title='Gender Distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ac05e7c-e6bd-4c96-8d64-c14c31c430d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ac05e7c-e6bd-4c96-8d64-c14c31c430d4")) {                    Plotly.newPlot(                        "2ac05e7c-e6bd-4c96-8d64-c14c31c430d4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"gender=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["male","male","male","male","male","male","female","male","male","male","male","male","female","female","male","female","male","female","female","male","male","female","female","female","male","female","male","male","male","male","female","female","female","female","male","female","male","female","female","male","female","female","male","male","female","female","female","male","male","female","female","male","female","male","female","male","male","male","male","male","male","male","female","male","male","male","male","male","female","male","male","male","male","male","male","female","female","male","male","female","female","male","male","male","male","female","male","male","female","female","female","male","female","male","male","male","female","female","female","male","female","male","female","male","male","male","male","male","male","male","female","male","male","female","male","female","male","male","male","male","male","female","female","male","male","female","female","female","male","male","male","female","male","male","female","female","female","male","female","male","male","male","male","male","male","male","male","male","female","male","male","male","female","male","male","male","male","male","male","male","male","male","male","male","female","female","male","male","female","male","female","male","male","female","male","male","female","female","male","female","male","male","male","male","female","female","female","male","male","female","female","male","male","female","male","male","male","female","female","male","male","male","male","male","female","male","male","male","female","male","male","male","male","female","male"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %%
gender=data.groupby(['gender']).size().reset_index(name="Count")
gender['gender'] = pd.Categorical(gender['gender'],categories=["male","female"],ordered=True)
gender=gender.sort_values(by=['gender','Count'])
px.bar(gender,x='gender',y="Count",color='gender',title="Gender Distribution by Count",color_discrete_sequence=['blue','powderblue'],text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a0af53c5-f3be-4a9c-84a7-ebd4bcefd879" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0af53c5-f3be-4a9c-84a7-ebd4bcefd879")) {                    Plotly.newPlot(                        "a0af53c5-f3be-4a9c-84a7-ebd4bcefd879",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"blue","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["male"],"xaxis":"x","y":[139],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"powderblue","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["female"],"xaxis":"x","y":[76],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %%
status = data.groupby(['status']).size().reset_index(name='count')
status['status'] = pd.Categorical(status['status'],categories=['Placed','Not Placed'],ordered=True)
status = status.sort_values(by=['status','count'])
px.bar(status,x='status',y='count',color='status',title="Placement Status Distribution",color_discrete_sequence=['green','red'],text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95c87c61-87f0-456c-b9fb-9fd434d5ab73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95c87c61-87f0-456c-b9fb-9fd434d5ab73")) {                    Plotly.newPlot(                        "95c87c61-87f0-456c-b9fb-9fd434d5ab73",                        [{"alignmentgroup":"True","hovertemplate":"status=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Placed","marker":{"color":"green","pattern":{"shape":""}},"name":"Placed","offsetgroup":"Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Placed"],"xaxis":"x","y":[148],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not Placed","marker":{"color":"red","pattern":{"shape":""}},"name":"Not Placed","offsetgroup":"Not Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Not Placed"],"xaxis":"x","y":[67],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth": ...

# %%
program = data.groupby(['specialisation']).size().reset_index(name='count')
program = program.sort_values(by=['count'])
px.bar(program,x='specialisation',y='count',title="Specialization Distribution",color = 'specialisation',text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="27f1e06e-2779-485c-983b-5e9ab65e06c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27f1e06e-2779-485c-983b-5e9ab65e06c2")) {                    Plotly.newPlot(                        "27f1e06e-2779-485c-983b-5e9ab65e06c2",                        [{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Java","offsetgroup":"Java","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Java"],"xaxis":"x","y":[18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"frontend","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"frontend","offsetgroup":"frontend","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["frontend"],"xaxis":"x","y":[20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"c","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"c","offsetgroup":"c","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["c"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"python","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"python","offsetgroup":"python","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["python"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"c++","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"c++","offsetgroup":"c++","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["c++"],"xaxis":"x","y":[92],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777 ...

# %%
fig = px.pie(program,names='specialisation',hole = 0.6)
fig.update_traces(textposition='inside', textinfo='percent+label',title='Distribution of Specialisation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d1fe7f3d-776e-42fe-84fa-f8c4b7e9e0de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1fe7f3d-776e-42fe-84fa-f8c4b7e9e0de")) {                    Plotly.newPlot(                        "d1fe7f3d-776e-42fe-84fa-f8c4b7e9e0de",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"specialisation=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Java","frontend","c","python","c++"],"legendgroup":"","name":"","showlegend":true,"type":"pie","textinfo":"percent+label","textposition":"inside","title":{"text":"Distribution of Specialisation"}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"s ...

# %%
gender_placement_counts = data.groupby(['gender', 'status']).size().reset_index(name='Count')
gender_placement_counts['gender'] = pd.Categorical(gender_placement_counts['gender'], categories=['male', 'female'], ordered=True)
gender_placement_counts = gender_placement_counts.sort_values(by=['gender', 'status'])
fig = px.line_3d(data, x="gender", y="specialisation",
                 z="status", color="gender",title="Gender, Specialization, and Status Interaction")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4aaf1fa6-8de9-4d09-8cf9-863832eab749" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aaf1fa6-8de9-4d09-8cf9-863832eab749")) {                    Plotly.newPlot(                        "4aaf1fa6-8de9-4d09-8cf9-863832eab749",                        [{"hovertemplate":"gender=%{x}\u003cbr\u003especialisation=%{y}\u003cbr\u003estatus=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"male","scene":"scene","showlegend":true,"x":["male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male"],"y":["Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","python","python","python","python","python","python","python","python","python"],"z":["Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed"," ...

# %%
fig = px.scatter_3d(data, x = 'workex',
                    y = 'specialisation',
                    z = 'status',
                    color = 'workex',
                    title="Work Experience, Specialization, and Status Interaction")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bbf2b4f3-55f1-499e-9107-7239a34632ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbf2b4f3-55f1-499e-9107-7239a34632ba")) {                    Plotly.newPlot(                        "bbf2b4f3-55f1-499e-9107-7239a34632ba",                        [{"hovertemplate":"workex=%{x}\u003cbr\u003especialisation=%{y}\u003cbr\u003estatus=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"No","scene":"scene","showlegend":true,"x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No"],"y":["Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","Java","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","python","python","python","python","python","python","python","python","python"],"z":["Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Pl ...

# %%
fig = px.bar(
    gender_placement_counts,
    x='gender',
    y='Count',
    color='status',
    barmode='group',
    title='Gender Distribution in Placed and Not Placed Categories',
    color_discrete_sequence=['red','green'],
    text_auto=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dc97f520-7832-4138-b5e4-5b2a9b2c676d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc97f520-7832-4138-b5e4-5b2a9b2c676d")) {                    Plotly.newPlot(                        "dc97f520-7832-4138-b5e4-5b2a9b2c676d",                        [{"alignmentgroup":"True","hovertemplate":"status=Not Placed\u003cbr\u003egender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not Placed","marker":{"color":"red","pattern":{"shape":""}},"name":"Not Placed","offsetgroup":"Not Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["male","female"],"xaxis":"x","y":[39,28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Placed\u003cbr\u003egender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Placed","marker":{"color":"green","pattern":{"shape":""}},"name":"Placed","offsetgroup":"Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["male","female"],"xaxis":"x","y":[100,48],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatt ...

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1    male  67.00   Others  91.00   Others  commerce     58.00
# 1        2    male  79.33  Central  78.33   Others   Science     77.48
# 2        3    male  65.00  Central  68.00  Central      Arts     64.00
# 3        4    male  56.00  Central  52.00  Central   Science     52.00
# 4        5    male  85.80  Central  73.60  Central  commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211    male  80.60   Others  82.00   Others  commerce     77.60
# 211    212    male  58.00   Others  60.00   Others   Science     72.00
# 212    213    male  67.00   Others  67.00   Others  commerce     73.00
# 213    214  female  74.00   Others  66.00   Others  commerce     58.00
# 214    215    male  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  project specialisation      status    salary
# 0     Sci&Tech     No        2           Java      Placed  270000.0
# 1     Sci&Tech    Yes        2           Java      Placed  200000.0
# 2    Comm&Mgmt     No        2           Java      Placed  250000.0
# 3     Sci&Tech     No        2           Java  Not Placed       NaN
# 4    Comm&Mgmt     No        2           Java      Placed  425000.0
# ..         ...    ...      ...            ...         ...       ...
# 210  Comm&Mgmt     No        2         python      Placed  400000.0
# 211   Sci&Tech     No        2         python      Placed  275000.0
# 212  Comm&Mgmt    Yes        2         python      Placed  295000.0
# 213  Comm&Mgmt     No        2         python      Placed  204000.0
# 214  Comm&Mgmt     No        2         python  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
ssc=data.groupby(['ssc_p','status']).size().reset_index(name='count')
ssc['status']=pd.Categorical(ssc['status'],categories=['Placed','Not Placed'],ordered=True)
px.bar(ssc,x='status',y='ssc_p',color='ssc_p',title="Placement Status by SSC Percentage")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="abb1a902-a167-43ff-b228-4b0fc0819abf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abb1a902-a167-43ff-b228-4b0fc0819abf")) {                    Plotly.newPlot(                        "abb1a902-a167-43ff-b228-4b0fc0819abf",                        [{"alignmentgroup":"True","hovertemplate":"status=%{x}\u003cbr\u003essc_p=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[40.89,41.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,49.0,50.0,51.0,51.57,52.0,52.58,52.6,53.0,54.0,54.2,54.4,55.0,55.6,55.68,56.0,56.28,56.6,58.0,58.0,59.0,59.0,59.6,59.96,60.0,60.23,60.4,60.8,61.0,61.0,61.08,61.8,62.0,62.0,63.0,63.0,63.3,63.4,64.0,64.0,64.6,65.0,65.2,66.0,66.0,66.5,67.0,67.0,67.16,67.9,68.0,68.2,69.0,69.0,69.5,69.6,69.7,69.8,70.0,70.5,70.89,71.0,72.0,73.0,73.24,73.96,74.0,74.0,74.2,74.9,75.0,75.2,75.4,76.0,76.0,76.5,76.7,76.76,77.0,77.4,77.44,77.67,77.8,78.0,78.5,79.0,79.33,80.0,80.4,80.6,80.92,81.0,81.7,82.0,83.0,83.33,83.84,83.96,84.0,84.2,84.86,85.0,85.8,86.5,87.0,88.0,89.4],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed"],"xaxis":"x","y":[40.89,41.0,43.0,44.0,45.0,46.0,47.0,48.0,49.0,49.0,50.0,51.0,51.57,52.0,52.58,52.6,53.0,54.0,54.2,54.4,55.0,55.6,55.68,56.0,56.28,56.6,58.0,58.0,59.0,59.0,59.6,59.96,60.0,60.23,60.4,60.8,61.0,61.0,61.08,61.8,62.0,62.0,63.0,63.0,63.3,63.4,64.0,64.0,64.6,65.0,65.2,66.0,66.0,66.5,67.0,67.0,67.16,67.9,68.0,68.2,69.0,69.0,69.5,69.6,69.7,69.8,70.0,70.5,70.89,71.0,72.0,73.0,73.24,73.96,74.0,74.0,74.2,74.9,75.0,75.2,75.4,76.0,76.0,76.5,76.7,76.76,77.0,77.4,77.44,77.67,77.8,78.0,78.5,79.0,79.33,80.0,80.4,80.6,80.92,81.0,81.7,82.0,83.0,83.33,83.84,83.96,84.0,84.2,84.86,85.0,85.8,86.5,87.0,88.0,89.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0. ...

# %%
hsc=data.groupby(['hsc_p','status']).size().reset_index(name='count')
px.bar(hsc,x='status',y='hsc_p',color='hsc_p',title = "Placement Status by HSC Percentage")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="714ad2af-83a4-43f6-bb69-cad0fe4f519a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("714ad2af-83a4-43f6-bb69-cad0fe4f519a")) {                    Plotly.newPlot(                        "714ad2af-83a4-43f6-bb69-cad0fe4f519a",                        [{"alignmentgroup":"True","hovertemplate":"status=%{x}\u003cbr\u003ehsc_p=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[37.0,39.0,40.0,42.0,42.16,44.0,45.83,47.0,49.0,49.2,49.8,50.0,50.83,51.0,52.0,53.0,53.0,54.0,54.6,55.0,56.0,57.0,57.0,58.0,58.0,58.66,59.0,59.0,60.0,60.0,60.33,60.5,60.8,61.0,61.12,61.33,61.4,62.0,62.0,62.5,62.5,62.83,63.0,63.0,63.16,64.0,64.0,64.2,64.8,64.89,65.0,65.0,65.5,65.58,65.66,66.0,66.0,66.2,66.6,66.8,67.0,67.0,67.2,68.0,68.4,69.0,69.4,70.0,70.0,70.2,70.29,70.4,71.0,71.4,71.5,71.98,72.0,72.5,72.8,73.0,73.2,73.4,73.5,73.6,74.0,74.66,75.0,76.0,76.5,77.0,77.6,78.0,78.33,78.33,78.5,79.0,80.0,81.0,82.0,82.0,83.83,86.0,87.0,87.6,89.7,89.83,90.0,90.9,91.0,92.0,97.0,97.7],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed"],"xaxis":"x","y":[37.0,39.0,40.0,42.0,42.16,44.0,45.83,47.0,49.0,49.2,49.8,50.0,50.83,51.0,52.0,53.0,53.0,54.0,54.6,55.0,56.0,57.0,57.0,58.0,58.0,58.66,59.0,59.0,60.0,60.0,60.33,60.5,60.8,61.0,61.12,61.33,61.4,62.0,62.0,62.5,62.5,62.83,63.0,63.0,63.16,64.0,64.0,64.2,64.8,64.89,65.0,65.0,65.5,65.58,65.66,66.0,66.0,66.2,66.6,66.8,67.0,67.0,67.2,68.0,68.4,69.0,69.4,70.0,70.0,70.2,70.29,70.4,71.0,71.4,71.5,71.98,72.0,72.5,72.8,73.0,73.2,73.4,73.5,73.6,74.0,74.66,75.0,76.0,76.5,77.0,77.6,78.0,78.33,78.33,78.5,79.0,80.0,81.0,82.0,82.0,83.83,86.0,87.0,87.6,89.7,89.83,90.0,90.9,91.0,92.0,97.0,97.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %%
degree_p=data.groupby(['degree_p','status']).size().reset_index(name='count')
px.bar(degree_p,x='status',y='degree_p',color='degree_p',title="Placement Status by Degree Percentage")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4a6c054d-19a1-47d9-ba2d-c0b1df76cf76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a6c054d-19a1-47d9-ba2d-c0b1df76cf76")) {                    Plotly.newPlot(                        "4a6c054d-19a1-47d9-ba2d-c0b1df76cf76",                        [{"alignmentgroup":"True","hovertemplate":"status=%{x}\u003cbr\u003edegree_p=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[50.0,50.2,50.8,52.0,53.0,54.0,54.38,55.0,56.0,56.2,56.3,56.87,57.0,57.0,57.5,58.0,58.0,59.0,59.0,59.79,59.9,60.0,60.0,60.9,61.0,61.0,61.26,61.4,62.0,62.8,63.0,63.35,64.0,64.0,64.2,64.21,64.27,64.33,64.5,64.6,64.74,64.8,65.0,65.0,65.6,65.6,66.0,66.0,66.4,66.6,66.89,67.0,67.0,67.25,67.4,67.5,68.0,68.4,69.0,69.2,69.3,69.5,69.6,70.0,70.2,70.67,71.0,71.25,71.72,71.93,72.0,72.0,72.11,72.23,72.7,73.0,73.3,73.43,74.0,74.0,75.0,75.5,76.0,77.0,77.2,77.25,77.48,77.5,77.5,77.6,77.72,78.0,78.3,78.86,79.0,79.0,80.0,81.0,82.0,83.0,84.0,85.0,91.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Not Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Not Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed","Placed"],"xaxis":"x","y":[50.0,50.2,50.8,52.0,53.0,54.0,54.38,55.0,56.0,56.2,56.3,56.87,57.0,57.0,57.5,58.0,58.0,59.0,59.0,59.79,59.9,60.0,60.0,60.9,61.0,61.0,61.26,61.4,62.0,62.8,63.0,63.35,64.0,64.0,64.2,64.21,64.27,64.33,64.5,64.6,64.74,64.8,65.0,65.0,65.6,65.6,66.0,66.0,66.4,66.6,66.89,67.0,67.0,67.25,67.4,67.5,68.0,68.4,69.0,69.2,69.3,69.5,69.6,70.0,70.2,70.67,71.0,71.25,71.72,71.93,72.0,72.0,72.11,72.23,72.7,73.0,73.3,73.43,74.0,74.0,75.0,75.5,76.0,77.0,77.2,77.25,77.48,77.5,77.5,77.6,77.72,78.0,78.3,78.86,79.0,79.0,80.0,81.0,82.0,83.0,84.0,85.0,91.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0 ...

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1    male  67.00   Others  91.00   Others  commerce     58.00
# 1        2    male  79.33  Central  78.33   Others   Science     77.48
# 2        3    male  65.00  Central  68.00  Central      Arts     64.00
# 3        4    male  56.00  Central  52.00  Central   Science     52.00
# 4        5    male  85.80  Central  73.60  Central  commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211    male  80.60   Others  82.00   Others  commerce     77.60
# 211    212    male  58.00   Others  60.00   Others   Science     72.00
# 212    213    male  67.00   Others  67.00   Others  commerce     73.00
# 213    214  female  74.00   Others  66.00   Others  commerce     58.00
# 214    215    male  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  project specialisation      status    salary
# 0     Sci&Tech     No        2           Java      Placed  270000.0
# 1     Sci&Tech    Yes        2           Java      Placed  200000.0
# 2    Comm&Mgmt     No        2           Java      Placed  250000.0
# 3     Sci&Tech     No        2           Java  Not Placed       NaN
# 4    Comm&Mgmt     No        2           Java      Placed  425000.0
# ..         ...    ...      ...            ...         ...       ...
# 210  Comm&Mgmt     No        2         python      Placed  400000.0
# 211   Sci&Tech     No        2         python      Placed  275000.0
# 212  Comm&Mgmt    Yes        2         python      Placed  295000.0
# 213  Comm&Mgmt     No        2         python      Placed  204000.0
# 214  Comm&Mgmt     No        2         python  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
land_placement_counts = data.groupby(['specialisation', 'status']).size().reset_index(name='Count')
land_placement_counts
# Out:
#   specialisation      status  Count
# 0           Java  Not Placed      7
# 1           Java      Placed     11
# 2              c  Not Placed     11
# 3              c      Placed     21
# 4            c++  Not Placed     29
# 5            c++      Placed     63
# 6       frontend  Not Placed      4
# 7       frontend      Placed     16
# 8         python  Not Placed     16
# 9         python      Placed     37

# %%
fig = px.bar(
    land_placement_counts,
    x='specialisation',
    y='Count',
    color='status',
    barmode='group',
    color_discrete_sequence=['red','green'],
    text_auto='specialisation'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0bdbe88-befa-47d6-8a2a-523a76941e4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0bdbe88-befa-47d6-8a2a-523a76941e4b")) {                    Plotly.newPlot(                        "c0bdbe88-befa-47d6-8a2a-523a76941e4b",                        [{"alignmentgroup":"True","hovertemplate":"status=Not Placed\u003cbr\u003especialisation=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not Placed","marker":{"color":"red","pattern":{"shape":""}},"name":"Not Placed","offsetgroup":"Not Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:specialisation}","x":["Java","c","c++","frontend","python"],"xaxis":"x","y":[7,11,29,4,16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Placed\u003cbr\u003especialisation=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Placed","marker":{"color":"green","pattern":{"shape":""}},"name":"Placed","offsetgroup":"Placed","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:specialisation}","x":["Java","c","c++","frontend","python"],"xaxis":"x","y":[11,21,63,16,37],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth": ...

# %%
salary_placement_counts = data.groupby(['specialisation', 'salary']).size().reset_index(name='Count')
salary_placement_counts
# Out:
#    specialisation    salary  Count
# 0            Java  200000.0      2
# 1            Java  218000.0      1
# 2            Java  231000.0      1
# 3            Java  250000.0      2
# 4            Java  252000.0      1
# ..            ...       ...    ...
# 79         python  360000.0      3
# 80         python  393000.0      1
# 81         python  400000.0      1
# 82         python  411000.0      1
# 83         python  450000.0      1
#
# [84 rows x 3 columns]

# %%
fig = px.bar(
    salary_placement_counts,
    x='specialisation',
    y='Count',
    color='salary',
    # barmode='group',
    title="Salary Distribution by Specialization",
    # color_discrete_sequence=['red','green']
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48dc103c-fe79-4041-a429-8bb9673d1136" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48dc103c-fe79-4041-a429-8bb9673d1136")) {                    Plotly.newPlot(                        "48dc103c-fe79-4041-a429-8bb9673d1136",                        [{"alignmentgroup":"True","hovertemplate":"specialisation=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esalary=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[200000.0,218000.0,231000.0,250000.0,252000.0,260000.0,270000.0,300000.0,425000.0,200000.0,210000.0,220000.0,230000.0,240000.0,250000.0,260000.0,300000.0,360000.0,380000.0,400000.0,420000.0,200000.0,210000.0,216000.0,220000.0,225000.0,233000.0,236000.0,240000.0,250000.0,252000.0,255000.0,260000.0,264000.0,265000.0,270000.0,275000.0,276000.0,280000.0,285000.0,290000.0,300000.0,340000.0,350000.0,360000.0,400000.0,500000.0,650000.0,690000.0,940000.0,218000.0,230000.0,240000.0,260000.0,265000.0,270000.0,275000.0,300000.0,336000.0,360000.0,500000.0,200000.0,204000.0,210000.0,216000.0,220000.0,236000.0,240000.0,250000.0,260000.0,265000.0,268000.0,275000.0,278000.0,287000.0,295000.0,300000.0,320000.0,350000.0,360000.0,393000.0,400000.0,411000.0,450000.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Java","Java","Java","Java","Java","Java","Java","Java","Java","c","c","c","c","c","c","c","c","c","c","c","c","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","c++","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","frontend","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python","python"],"xaxis":"x","y":[2,1,1,2,1,1,1,1,1,1,2,2,1,2,1,1,7,1,1,1,1,1,1,1,2,1,1,1,6,12,1,1,2,1,3,2,1,2,2,1,1,9,1,2,1,2,2,1,1,1,1,1,4,1,1,1,3,1,1,1,1,2,2,1,2,1,1,3,3,2,2,1,1,1,1,1,4,1,1,3,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %%
exp = data.groupby(['gender','workex']).size().reset_index(name='count')
exp['gender'] = pd.Categorical(exp['gender'],categories=['male','female'],ordered=True)
exp =exp.sort_values(by=['gender'])

# %%
fig = px.bar(
    exp,
    x='gender',
    y='count',
    color='workex',
    color_discrete_sequence=['red','blue'],
    title="Work Experience Distribution by Gender"
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="184da5ef-05e0-4fc5-9801-42f6ebe6ed4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("184da5ef-05e0-4fc5-9801-42f6ebe6ed4d")) {                    Plotly.newPlot(                        "184da5ef-05e0-4fc5-9801-42f6ebe6ed4d",                        [{"alignmentgroup":"True","hovertemplate":"workex=No\u003cbr\u003egender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"red","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["male","female"],"xaxis":"x","y":[87,54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"workex=Yes\u003cbr\u003egender=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"blue","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["male","female"],"xaxis":"x","y":[52,22],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1    male  67.00   Others  91.00   Others  commerce     58.00
# 1        2    male  79.33  Central  78.33   Others   Science     77.48
# 2        3    male  65.00  Central  68.00  Central      Arts     64.00
# 3        4    male  56.00  Central  52.00  Central   Science     52.00
# 4        5    male  85.80  Central  73.60  Central  commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211    male  80.60   Others  82.00   Others  commerce     77.60
# 211    212    male  58.00   Others  60.00   Others   Science     72.00
# 212    213    male  67.00   Others  67.00   Others  commerce     73.00
# 213    214  female  74.00   Others  66.00   Others  commerce     58.00
# 214    215    male  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  project specialisation      status    salary
# 0     Sci&Tech     No        2           Java      Placed  270000.0
# 1     Sci&Tech    Yes        2           Java      Placed  200000.0
# 2    Comm&Mgmt     No        2           Java      Placed  250000.0
# 3     Sci&Tech     No        2           Java  Not Placed       NaN
# 4    Comm&Mgmt     No        2           Java      Placed  425000.0
# ..         ...    ...      ...            ...         ...       ...
# 210  Comm&Mgmt     No        2         python      Placed  400000.0
# 211   Sci&Tech     No        2         python      Placed  275000.0
# 212  Comm&Mgmt    Yes        2         python      Placed  295000.0
# 213  Comm&Mgmt     No        2         python      Placed  204000.0
# 214  Comm&Mgmt     No        2         python  Not Placed       NaN
#
# [215 rows x 14 columns]

# %% [markdown]
# Data Preprocessing

# %%
data.shape
# Out:
# (215, 14)

# %%
data.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# project             int64
# specialisation     object
# status             object
# salary            float64
# dtype: object

# %%
data.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# project            0
# specialisation     0
# status             0
# salary            67
# dtype: int64

# %%
df1 = data.copy()
df1.drop(['sl_no','ssc_b','hsc_b'],axis=1,inplace=True)
df1
# Out:
#      gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  project  \
# 0      male  67.00  91.00  commerce     58.00   Sci&Tech     No        2
# 1      male  79.33  78.33   Science     77.48   Sci&Tech    Yes        2
# 2      male  65.00  68.00      Arts     64.00  Comm&Mgmt     No        2
# 3      male  56.00  52.00   Science     52.00   Sci&Tech     No        2
# 4      male  85.80  73.60  commerce     73.30  Comm&Mgmt     No        2
# ..      ...    ...    ...       ...       ...        ...    ...      ...
# 210    male  80.60  82.00  commerce     77.60  Comm&Mgmt     No        2
# 211    male  58.00  60.00   Science     72.00   Sci&Tech     No        2
# 212    male  67.00  67.00  commerce     73.00  Comm&Mgmt    Yes        2
# 213  female  74.00  66.00  commerce     58.00  Comm&Mgmt     No        2
# 214    male  62.00  58.00   Science     53.00  Comm&Mgmt     No        2
#
#     specialisation      status    salary
# 0             Java      Placed  270000.0
# 1             Java      Placed  200000.0
# 2             Java      Placed  250000.0
# 3             Java  Not Placed       NaN
# 4             Java      Placed  425000.0
# ..             ...         ...       ...
# 210         python      Placed  400000.0
# 211         python      Placed  275000.0
# 212         python      Placed  295000.0
# 213         python      Placed  204000.0
# 214         python  Not Placed       NaN
#
# [215 rows x 11 columns]

# %%
degree_t = {'Sci&Tech':2,
            'Comm&Mgmt':0,
            'Others':1}
gender = {'male':1,'female':0}
hsc_s= {'commerceerce':2,
        'Science':1,
        'Arts':0}
work_ex = {'No':0,'Yes':1}
specialisation = {'Java':0,'python':4,'frontend':3,'c':1,'c++':2}

# %%
data['specialisation'].unique()
# Out:
# array(['Java', 'python', 'frontend', 'c', 'c++'], dtype=object)

# %%
df1['specialisation'].unique()
# Out:
# array(['Java', 'python', 'frontend', 'c', 'c++'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
lst=['gender','hsc_s','degree_t','workex','specialisation','status']
for i in lst:
  df1[i]=le.fit_transform(df1[i])

df1
# Out:
#      gender  ssc_p  hsc_p  hsc_s  degree_p  degree_t  workex  project  \
# 0         1  67.00  91.00      2     58.00         2       0        2
# 1         1  79.33  78.33      1     77.48         2       1        2
# 2         1  65.00  68.00      0     64.00         0       0        2
# 3         1  56.00  52.00      1     52.00         2       0        2
# 4         1  85.80  73.60      2     73.30         0       0        2
# ..      ...    ...    ...    ...       ...       ...     ...      ...
# 210       1  80.60  82.00      2     77.60         0       0        2
# 211       1  58.00  60.00      1     72.00         2       0        2
# 212       1  67.00  67.00      2     73.00         0       1        2
# 213       0  74.00  66.00      2     58.00         0       0        2
# 214       1  62.00  58.00      1     53.00         0       0        2
#
#      specialisation  status    salary
# 0                 0       1  270000.0
# 1                 0       1  200000.0
# 2                 0       1  250000.0
# 3                 0       0       NaN
# 4                 0       1  425000.0
# ..              ...     ...       ...
# 210               4       1  400000.0
# 211               4       1  275000.0
# 212               4       1  295000.0
# 213               4       1  204000.0
# 214               4       0       NaN
#
# [215 rows x 11 columns]

# %%
df1['salary']=df1['salary'].fillna(df1['salary'].mode()[0])
df1
# Out:
#      gender  ssc_p  hsc_p  hsc_s  degree_p  degree_t  workex  project  \
# 0         1  67.00  91.00      2     58.00         2       0        2
# 1         1  79.33  78.33      1     77.48         2       1        2
# 2         1  65.00  68.00      0     64.00         0       0        2
# 3         1  56.00  52.00      1     52.00         2       0        2
# 4         1  85.80  73.60      2     73.30         0       0        2
# ..      ...    ...    ...    ...       ...       ...     ...      ...
# 210       1  80.60  82.00      2     77.60         0       0        2
# 211       1  58.00  60.00      1     72.00         2       0        2
# 212       1  67.00  67.00      2     73.00         0       1        2
# 213       0  74.00  66.00      2     58.00         0       0        2
# 214       1  62.00  58.00      1     53.00         0       0        2
#
#      specialisation  status    salary
# 0                 0       1  270000.0
# 1                 0       1  200000.0
# 2                 0       1  250000.0
# 3                 0       0  300000.0
# 4                 0       1  425000.0
# ..              ...     ...       ...
# 210               4       1  400000.0
# 211               4       1  275000.0
# 212               4       1  295000.0
# 213               4       1  204000.0
# 214               4       0  300000.0
#
# [215 rows x 11 columns]

# %%
X=df1.drop(['status'],axis=1)
y=df1['status']

# %%
X=df1.iloc[:,:9]
y=df1.iloc[:,-2]

# %%
X
# Out:
#      gender  ssc_p  hsc_p  hsc_s  degree_p  degree_t  workex  project  \
# 0         1  67.00  91.00      2     58.00         2       0        2
# 1         1  79.33  78.33      1     77.48         2       1        2
# 2         1  65.00  68.00      0     64.00         0       0        2
# 3         1  56.00  52.00      1     52.00         2       0        2
# 4         1  85.80  73.60      2     73.30         0       0        2
# ..      ...    ...    ...    ...       ...       ...     ...      ...
# 210       1  80.60  82.00      2     77.60         0       0        2
# 211       1  58.00  60.00      1     72.00         2       0        2
# 212       1  67.00  67.00      2     73.00         0       1        2
# 213       0  74.00  66.00      2     58.00         0       0        2
# 214       1  62.00  58.00      1     53.00         0       0        2
#
#      specialisation
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 210               4
# 211               4
# 212               4
# 213               4
# 214               4
#
# [215 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 210    1
# 211    1
# 212    1
# 213    1
# 214    0
# Name: status, Length: 215, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
X_sc=ms.fit_transform(X)
X_sc
# Out:
# array([[1.        , 0.53823954, 0.88962109, ..., 0.        , 0.33333333,
#         0.        ],
#        [1.        , 0.79241394, 0.68088962, ..., 1.        , 0.33333333,
#         0.        ],
#        [1.        , 0.49701093, 0.5107084 , ..., 0.        , 0.33333333,
#         0.        ],
#        ...,
#        [1.        , 0.53823954, 0.49423394, ..., 1.        , 0.33333333,
#         1.        ],
#        [0.        , 0.68253968, 0.47775947, ..., 0.        , 0.33333333,
#         1.        ],
#        [1.        , 0.43516801, 0.34596376, ..., 0.        , 0.33333333,
#         1.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
joblib.dump(nb, 'GaussianNB.pkl')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=1)
rf.fit(X_train,y_train)
y_pred4=rf.predict(X_test)
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.53      0.70        15
#            1       0.80      1.00      0.89        28
#
#     accuracy                           0.84        43
#    macro avg       0.90      0.77      0.79        43
# weighted avg       0.87      0.84      0.82        43

# %%
df1
# Out:
#      gender  ssc_p  hsc_p  hsc_s  degree_p  degree_t  workex  project  \
# 0         1  67.00  91.00      2     58.00         2       0        2
# 1         1  79.33  78.33      1     77.48         2       1        2
# 2         1  65.00  68.00      0     64.00         0       0        2
# 3         1  56.00  52.00      1     52.00         2       0        2
# 4         1  85.80  73.60      2     73.30         0       0        2
# ..      ...    ...    ...    ...       ...       ...     ...      ...
# 210       1  80.60  82.00      2     77.60         0       0        2
# 211       1  58.00  60.00      1     72.00         2       0        2
# 212       1  67.00  67.00      2     73.00         0       1        2
# 213       0  74.00  66.00      2     58.00         0       0        2
# 214       1  62.00  58.00      1     53.00         0       0        2
#
#      specialisation  status    salary
# 0                 0       1  270000.0
# 1                 0       1  200000.0
# 2                 0       1  250000.0
# 3                 0       0  300000.0
# 4                 0       1  425000.0
# ..              ...     ...       ...
# 210               4       1  400000.0
# 211               4       1  275000.0
# 212               4       1  295000.0
# 213               4       1  204000.0
# 214               4       0  300000.0
#
# [215 rows x 11 columns]

# %%
degree_t_dict = {'Sci&Tech':2,
            'Comm&Mgmt':0,
            'Others':1}
gender_dict = {'male':1,'female':0}
hsc_s_dict = {'commerce':2,
        'Science':1,
        'Arts':0}
work_ex_dict = {'No':0,'Yes':1}
specialisation_dict = {'Java':0,'python':4,'frontend':3,'c':1,'c++':2}

# %%
import numpy as np

# %%
data
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1    male  67.00   Others  91.00   Others  commerce     58.00
# 1        2    male  79.33  Central  78.33   Others   Science     77.48
# 2        3    male  65.00  Central  68.00  Central      Arts     64.00
# 3        4    male  56.00  Central  52.00  Central   Science     52.00
# 4        5    male  85.80  Central  73.60  Central  commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211    male  80.60   Others  82.00   Others  commerce     77.60
# 211    212    male  58.00   Others  60.00   Others   Science     72.00
# 212    213    male  67.00   Others  67.00   Others  commerce     73.00
# 213    214  female  74.00   Others  66.00   Others  commerce     58.00
# 214    215    male  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  project specialisation      status    salary
# 0     Sci&Tech     No        2           Java      Placed  270000.0
# 1     Sci&Tech    Yes        2           Java      Placed  200000.0
# 2    Comm&Mgmt     No        2           Java      Placed  250000.0
# 3     Sci&Tech     No        2           Java  Not Placed       NaN
# 4    Comm&Mgmt     No        2           Java      Placed  425000.0
# ..         ...    ...      ...            ...         ...       ...
# 210  Comm&Mgmt     No        2         python      Placed  400000.0
# 211   Sci&Tech     No        2         python      Placed  275000.0
# 212  Comm&Mgmt    Yes        2         python      Placed  295000.0
# 213  Comm&Mgmt     No        2         python      Placed  204000.0
# 214  Comm&Mgmt     No        2         python  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
gender = str(input("enter the your gender:"))
ssc_p = float(input("enter the sslc percentage:"))
hsc_p = float(input("enter the hsc percentage:"))
hsc_s = str(input("enter the hsc course:"))
degree_p = float(input("enter the degree Percentage:"))
degree_t = str(input("enter the degree course:"))
workex = str(input("Do you have work experience:"))
project = int(input("enter the no of project you have done:"))
specialisation = str(input('enter the your prorgramming language:'))
gender_x = gender_dict[gender]
hsc_s_x = hsc_s_dict[hsc_s]
degree_t_x = degree_t_dict[degree_t]
work_ex_x = work_ex_dict[workex]
specialisation_x = specialisation_dict[specialisation]
# Out:
# enter the your gender:male
# enter the sslc percentage:75
# enter the hsc percentage:85
# enter the hsc course:Science
# enter the degree Percentage:70
# enter the degree course:Sci&Tech
# Do you have work experience:Yes
# enter the no of project you have done:2
# enter the your prorgramming language:python

# %%
gender_x = gender_dict[gender]
hsc_s_x = hsc_s_dict[hsc_s]
degree_t_x = degree_t_dict[degree_t]
work_ex_x = work_ex_dict[workex]
specialisation_x = specialisation_dict[specialisation]

# %%
x_pred = np.array([[gender_x,ssc_p,hsc_p,hsc_s_x,degree_p,degree_t_x,work_ex_x,project,specialisation_x]])
x_pred
mod=rf.predict(x_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names

# %%
if mod >= 0.5:
    print("Congratulations! You are likely to be placed.")
else:
    print("Sorry, you might not be placed.")
# Out:
# Congratulations! You are likely to be placed.

# %%
x_pred
# Out:
# array([[ 1., 75., 85.,  1., 70.,  2.,  1.,  2.,  4.]])

# %%
import joblib

# %%
joblib.dump(rf, 'RandomForest.pkl')
# Out:
# ['RandomForest.pkl']
